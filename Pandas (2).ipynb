# %% [markdown]
# Pandas

# %%
import pandas as pd
df=pd.read_csv("nyc_weather.csv")
df.head(10)
df.tail(30)
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 1    1/2/2016           36        18        46                 30.02
# 2    1/3/2016           40        21        47                 29.86
# 3    1/4/2016           25         9        44                 30.05
# 4    1/5/2016           20        -3        41                 30.57
# 5    1/6/2016           33         4        35                 30.50
# 6    1/7/2016           39        11        33                 30.28
# 7    1/8/2016           39        29        64                 30.20
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 10  1/11/2016           33         8        37                 29.92
# 11  1/12/2016           35        15        53                 29.85
# 12  1/13/2016           26         4        42                 29.94
# 13  1/14/2016           30        12        47                 29.95
# ...

# %%
df.Events
# Out:
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8         Rain
# 9         Rain
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15        Rain
# 16    Fog-Snow
# 17        Snow
# 18         NaN
# 19         NaN
# 20         NaN
# 21        Snow
# 22    Fog-Snow
# 23        Snow
# 24         NaN
# 25         NaN
# 26        Rain
# 27         NaN
# 28         NaN
# 29         NaN
# 30         NaN
# Name: Events, dtype: object

# %%
df.Humidity
# Out:
# 0     52
# 1     46
# 2     47
# 3     44
# 4     41
# 5     35
# 6     33
# 7     64
# 8     77
# 9     71
# 10    37
# 11    53
# 12    42
# 13    47
# 14    62
# 15    70
# 16    66
# 17    53
# 18    42
# 19    49
# 20    45
# 21    41
# 22    78
# 23    53
# 24    54
# 25    56
# 26    45
# 27    51
# 28    50
# 29    46
# 30    52
# Name: Humidity, dtype: int64

# %%
df.count()
# Out:
# EST                     31
# Temperature             31
# DewPoint                31
# Humidity                31
# Sea Level PressureIn    31
# VisibilityMiles         31
# WindSpeedMPH            28
# PrecipitationIn         31
# CloudCover              31
# Events                   9
# WindDirDegrees          31
# dtype: int64

# %%
df.Temperature.count()
# Out:
# np.int64(31)

# %%
df.describe()
# Out:
#        Temperature   DewPoint   Humidity  Sea Level PressureIn  \
# count    31.000000  31.000000  31.000000             31.000000
# mean     34.677419  17.838710  51.677419             29.992903
# std       7.639315  11.378626  11.634395              0.237237
# min      20.000000  -3.000000  33.000000             29.520000
# 25%      29.000000  10.000000  44.500000             29.855000
# 50%      35.000000  18.000000  50.000000             30.010000
# 75%      39.500000  23.000000  55.000000             30.140000
# max      50.000000  46.000000  78.000000             30.570000
#
#        VisibilityMiles  WindSpeedMPH  CloudCover  WindDirDegrees
# count        31.000000     28.000000   31.000000       31.000000
# mean          9.193548      6.892857    3.129032      247.129032
# std           1.939405      2.871821    2.629853       92.308086
# min           1.000000      2.000000    0.000000       34.000000
# 25%           9.000000      5.000000    1.000000      238.000000
# ...

# %%
df.WindSpeedMPH
# Out:
# 0      8.0
# 1      7.0
# 2      8.0
# 3      9.0
# 4      5.0
# 5      4.0
# 6      2.0
# 7      4.0
# 8      8.0
# 9      NaN
# 10     NaN
# 11     6.0
# 12    10.0
# 13     5.0
# 14     5.0
# 15     7.0
# 16     6.0
# 17    12.0
# 18    11.0
# 19     6.0
# 20     6.0
# 21     NaN
# 22    16.0
# 23     6.0
# 24     3.0
# 25     7.0
# 26     7.0
# 27     5.0
# 28     8.0
# 29     7.0
# 30     5.0
# Name: WindSpeedMPH, dtype: float64

# %%
df.WindSpeedMPH.isna()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# Name: WindSpeedMPH, dtype: bool

# %%
df.WindSpeedMPH.isna().sum()
# Out:
# np.int64(3)

# %%
df.dtypes
# Out:
# EST                      object
# Temperature               int64
# DewPoint                  int64
# Humidity                  int64
# Sea Level PressureIn    float64
# VisibilityMiles           int64
# WindSpeedMPH            float64
# PrecipitationIn          object
# CloudCover                int64
# Events                   object
# WindDirDegrees            int64
# dtype: object

# %%
df.Events.unique()
# Out:
# array([nan, 'Rain', 'Fog-Snow', 'Snow'], dtype=object)

# %%
df['Temperature'].max()
# Out:
# np.int64(50)

# %%
df['Temperature'].min()
# Out:
# np.int64(20)

# %%
df1=df['Temperature']>30
df1.sum()
# Out:
# np.int64(22)

# %%
df['Temperature'][df['Events']=='Rain']
# Out:
# 8     44
# 9     50
# 15    47
# 26    41
# Name: Temperature, dtype: int64

# %%
df['Temperature'][df['Events']=='Snow']
# Out:
# 17    25
# 21    26
# 23    28
# Name: Temperature, dtype: int64

# %%
lst=[10,20,30,40,50,60]
s=pd.Series(lst)
print(s,type(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
l1=[1,2,3]
ser=pd.Series(l1,index=['lst',2,'3rd'],name='c1')
print(ser)
# Out:
# lst    1
# 2      2
# 3rd    3
# Name: c1, dtype: int64

# %%
s=pd.Series([10,20,30,40,50,60])
print(s,type(s))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# 5    60
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
print(s.loc[0:3])
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
lst=[10,20,30,40,50,60,70]
s=pd.Series(lst,dtype='float32')
print(s,type(s))
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# 3    40.0
# 4    50.0
# 5    60.0
# 6    70.0
# dtype: float32 <class 'pandas.core.series.Series'>

# %%
s[2]
# Out:
# np.float32(30.0)

# %%
s.shape
# Out:
# (7,)

# %%
lst=[10,"Rossum",34.56,"Author"]
s=pd.Series(lst,index=["stno","Name","Marks","Desg"])
print(s,type(s))
# Out:
# stno         10
# Name     Rossum
# Marks     34.56
# Desg     Author
# dtype: object <class 'pandas.core.series.Series'>

# %%
s["stno"]
# Out:
# 10

# %%
d1={"sub1":"python","sub2":"java"}
print(d1,type(d1))
# Out:
# {'sub1': 'python', 'sub2': 'java'} <class 'dict'>

# %%
d1.items()
# Out:
# dict_items([('sub1', 'python'), ('sub2', 'java')])

# %%
d1.keys()
# Out:
# dict_keys(['sub1', 'sub2'])

# %%
d1.values()
# Out:
# dict_values(['python', 'java'])

# %%
d1={"sub1":"python","sub2":"java"}
s=pd.Series(d1)
print(s)
# Out:
# sub1    python
# sub2      java
# dtype: object

# %%
s["sub2"]
# Out:
# 'java'

# %% [markdown]
# DATA FRAME

# %%
lst=[[10,'RS'],[20,'JG'],[30,'MCK'],[40,'TRA']]
df=pd.DataFrame(lst)
print(df)
# Out:
#     0    1
# 0  10   RS
# 1  20   JG
# 2  30  MCK
# 3  40  TRA

# %%
df.iloc[2:,:]
# Out:
#       Rno Name
# 30     30  MCK
# four   40  TRA

# %%
df.iloc[3,1]
# Out:
# 'TRA'

# %%
lst=[[10,'RS'],[20,'JG'],[30,'MCK'],[40,'TRA']]
df=pd.DataFrame(lst,columns=["Rno","Name"],index=['1',20,30,"four"])
print(df)
# Out:
#       Rno Name
# 1      10   RS
# 20     20   JG
# 30     30  MCK
# four   40  TRA

# %%
lst=[[10,'RS'],[20,'JG'],[30,'MCK'],[40,'TRA']]
df=pd.DataFrame(lst,columns=["Slno","Name"])
print(df)
# Out:
#    Slno Name
# 0    10   RS
# 1    20   JG
# 2    30  MCK
# 3    40  TRA

# %% [markdown]
# DATAFRAME USING TUPLE

# %%
tpl=(("Ann",25),("Charlie",45),("John",35),("Anjana",22),("Sam",17))
s=pd.DataFrame(tpl,index=[100,101,102,103,104],columns=["Name","Age"])
print(s)
# Out:
#         Name  Age
# 100      Ann   25
# 101  Charlie   45
# 102     John   35
# 103   Anjana   22
# 104      Sam   17

# %%
s['salary']=[1,2,3,4,5]
print(s)
# Out:
#         Name  Age  salary
# 100      Ann   25       1
# 101  Charlie   45       2
# 102     John   35       3
# 103   Anjana   22       4
# 104      Sam   17       5

# %%
s.drop("salary",axis=1,inplace=True)
print(s)
# Out:
#         Name  Age
# 100      Ann   25
# 101  Charlie   45
# 102     John   35
# 103   Anjana   22
# 104      Sam   17

# %% [markdown]
# DATAFRAME USING DICT

# %%
dictdata={"names":["Ann","charlie","John","sam"],"Subjects":["Python","Java","C","Pandas"],"Ages":[14,34,56,23]}
print(dictdata)
# Out:
# {'names': ['Ann', 'charlie', 'John', 'sam'], 'Subjects': ['Python', 'Java', 'C', 'Pandas'], 'Ages': [14, 34, 56, 23]}

# %%
df=pd.DataFrame(dictdata)
print(df)
# Out:
#      names Subjects  Ages
# 0      Ann   Python    14
# 1  charlie     Java    34
# 2     John        C    56
# 3      sam   Pandas    23

# %%
df.shape
# Out:
# (4, 3)

# %%
df=pd.DataFrame(dictdata,index=["a","b","c","d"])
print(df)
# Out:
#      names Subjects  Ages
# a      Ann   Python    14
# b  charlie     Java    34
# c     John        C    56
# d      sam   Pandas    23

# %%
l=[10,20,30]
sdata=pd.Series(l)
print(sdata,type(sdata))
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
df=pd.DataFrame(l,columns=["Number"])
print(df)
# Out:
#    Number
# 0      10
# 1      20
# 2      30

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
d1={"totalmark":[100,200,300],"Extmarks":[27,78,680]}
df=pd.DataFrame(d1,index=[1,2,3])
print(df)
# Out:
#    totalmark  Extmarks
# 1        100        27
# 2        200        78
# 3        300       680

# %%
df.loc[2:,:]
# Out:
#    totalmark  Extmarks
# 2        200        78
# 3        300       680

# %%
df.columns
# Out:
# Index(['totalmark', 'Extmarks'], dtype='object')

# %% [markdown]
# Adding new col name to dataframe

# %%
df['c3']=df['totalmark']+df['Extmarks']
df
df.drop("c3",axis=1,inplace=True)
print(df)
# Out:
#    totalmark  Extmarks
# 1        100        27
# 2        200        78
# 3        300       680

# %%
df['sub']=df['totalmark']-df['Extmarks']
df
# Out:
#    totalmark  Extmarks  Final  sub     name newdata
# 1        100        27    127   73  kishore     1st
# 2        200        78    278  122    gokul     2nd
# 3        300       680    980 -380     arun     3rd

# %%
df['newcol']=[1,2,3]
df
# Out:
#    totalmark  Extmarks   c3  Final  sub  newcol
# 1        100        27  127    127   73       1
# 2        200        78  278    278  122       2
# 3        300       680  980    980 -380       3

# %%
df['newdata']=['1st','2nd','3rd']   #Adding new col
df
# Out:
#    totalmark  Extmarks newdata
# 1        100        27     1st
# 2        200        78     2nd
# 3        300       680     3rd

# %%
df['Roll_no']=range(1,4)
df
# Out:
#    totalmark  Extmarks newdata  Roll_no
# 1        100        27     1st        1
# 2        200        78     2nd        2
# 3        300       680     3rd        3

# %%
df=df[['totalmark','Extmarks','newdata']]
df # changing the column order
# Out:
#    totalmark  Extmarks newdata
# 1        100        27     1st
# 2        200        78     2nd
# 3        300       680     3rd

# %%
df1=df[['Roll_no','totalmark']]
df1
# Out:
#    Roll_no  totalmark
# 1        1        100
# 2        2        200
# 3        3        300

# %%
df=df.sort_values(['Roll_no'],ascending=False)      # for descending.......ascending=False
                                                    # for ascending..........ascending=True
df
# Out:
#    Roll_no  totalmark  Extmarks newdata
# 3        3        300       680     3rd
# 2        2        200        78     2nd
# 1        1        100        27     1st

# %%
df["name"]=["kishore","gokul","arun"]
df
# Out:
#    totalmark  Extmarks  Final  sub     name
# 1        100        27    127   73  kishore
# 2        200        78    278  122    gokul
# 3        300       680    980 -380     arun

# %%
import pandas as pd
df=pd.read_csv("data.csv")
df
# Out:
#       id  season        city        date                  team1  \
# 0      1    2008   Bangalore  2008-04-18  Kolkata Knight Riders
# 1      2    2008  Chandigarh  2008-04-19    Chennai Super Kings
# 2      3    2008       Delhi  2008-04-19       Rajasthan Royals
# 3      4    2008      Mumbai  2008-04-20         Mumbai Indians
# 4      5    2008     Kolkata  2008-04-20        Deccan Chargers
# ..   ...     ...         ...         ...                    ...
# 572  573    2016      Raipur  2016-05-22       Delhi Daredevils
# 573  574    2016   Bangalore  2016-05-24          Gujarat Lions
# 574  575    2016       Delhi  2016-05-25    Sunrisers Hyderabad
# 575  576    2016       Delhi  2016-05-27          Gujarat Lions
# 576  577    2016   Bangalore  2016-05-29    Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
df=df.sort_values(["team2"],ascending=True)
df.head(10)
df
# Out:
#       id  season        city        date                  team1  \
# 130  131    2010     Chennai  2010-03-21        Kings XI Punjab
# 274  275    2012     Chennai  2012-04-21       Rajasthan Royals
# 397  398    2013     Kolkata  2013-05-26         Mumbai Indians
# 204  205    2011      Mumbai  2011-04-27          Pune Warriors
# 197  198    2011      Mumbai  2011-04-22         Mumbai Indians
# ..   ...     ...         ...         ...                    ...
# 571  572    2016     Kolkata  2016-05-22  Kolkata Knight Riders
# 562  563    2016  Chandigarh  2016-05-15        Kings XI Punjab
# 550  551    2016   Hyderabad  2016-05-06          Gujarat Lions
# 406  407    2014     Sharjah  2014-04-22        Kings XI Punjab
# 531  532    2016      Rajkot  2016-04-21          Gujarat Lions
#
#                    team2          toss_winner toss_decision  result  \
# 130  Chennai Super Kings  Chennai Super Kings         field     tie
# ...

# %%
df.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               3
# win_by_runs          0
# win_by_wickets       0
# player_of_match      3
# venue                0
# umpire1              0
# umpire2              0
# umpire3            577
# dtype: int64

# %%
df.city
# Out:
# 130       Chennai
# 274       Chennai
# 397       Kolkata
# 204        Mumbai
# 197        Mumbai
#           ...
# 571       Kolkata
# 562    Chandigarh
# 550     Hyderabad
# 406       Sharjah
# 531        Rajkot
# Name: city, Length: 577, dtype: object
